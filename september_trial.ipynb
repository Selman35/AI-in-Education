# %%
'This is a trial to check whether the feature called auto-saving in every 30 seconds works or not.',
'the main reasons why i would like to check is that whenever an user is writing something for longer than 30 seconds it is important to check',
'whether those saves are logged or not author'
# Out:
# 'whether those saves are logged or not author'

# %%
'Today is september second and we are implementing a new feature called idle time checker. The point of this idle time checker is to see whether the code is able to capture when a student is not doing anything and still active in the notebook.'
# Out:
# 'Today is september second and we are implementing a new feature called idle time checker. The point of this idle time checker is to see whether the code is able to capture when a student is not doing anything and still active in the notebook.'

# %%
"Hello this is the beginning of the second trial to actually see whether something is happening or not"
# Out:
# 'Hello this is the beginning of the second trial to actually see whether something is happening or not'

# %%
'Hola'
# Out:
# 'Hola'

# %%
'hey'
# Out:
# 'hey'
