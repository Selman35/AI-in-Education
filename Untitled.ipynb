# %%
"Hello, this is the first trial of the project", "From what i have noticed it seems like it is working."
# Out:
# ('Hello, this is the first trial of the project',
#  'From what i have noticed it seems like it is working.')

# %%
"I would like to see what you are capable of doing. So I will be trying out bunch of different stuff in this cell. Let's see whether you can perform well or not."
# Out:
# "I would like to see what you are capable of doing. So I will be trying out bunch of different stuff in this cell. Let's see whether you can perform well or not."

# %%
 "I will now try to copy some stuff and see whether they would work out. This is is the first thing i will be pasting. :Since news broke last month that OpenAI agents colluded to cheat and launch a cyberattack in defiance of company safeguards, AI safety activists have been ringing the alarm. The incident underscored the reality that the AI industry has already lost control of its technology and has renewed calls for stringent regulations."
# Out:
# 'I will now try to copy some stuff and see whether they would work out. This is is the first thing i will be pasting. :Since news broke last month that OpenAI agents colluded to cheat and launch a cyberattack in defiance of company safeguards, AI safety activists have been ringing the alarm. The incident underscored the reality that the AI industry has already lost control of its technology and has renewed calls for stringent regulations.'

# %%
'Print', 'print'
# Out:
# ('Print', 'print')

# %%
def summation(integer_1: int, integer_2: int)-> int:
    total = integer_1 + integer_2
    return total

# %%
print(summation(2,4))
# Out:
# 6

# %%
print(summation(2,4))
# Out:
# 6

# %%
"
