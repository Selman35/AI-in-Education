# %%
"Hello, this is the first trial of the day. I would like to try to features that are implemented to see how they work and whether there are any error with anything"
# Out:
# 'Hello, this is the first trial of the day. I would like to try to features that are implemented to see how they work and whether there are any error with anything'

# %%
def funct(integer_1: int, string_1:str) -> str:
    new_str = string_1 + " " + str(integer_1)
    return new_str

# %%
print(funct(1, 'hello'))
# Out:
# hello 1

# %%
"This is the second session of trying to chekc whether everythign works or not. I would like to see whether the changes can be made and logged correctly in the system"
# Out:
# 'This is the second session of trying to chekc whether everythign works or not. I would like to see whether the changes can be made and logged correctly in the system'

# %%
"This should be the beginning of the second active session. I would like to see how the logs are savved."
# Out:
# 'This should be the beginning of the second active session. I would like to see how the logs are savved.'

# %%
print(funct(1, 'hello'))
# Out:
# hello 1
